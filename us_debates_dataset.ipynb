# %%
import json
import glob

import pyreadr
import pandas as pd

from tqdm import tqdm

tqdm.pandas()

# %%
data = pyreadr.read_r("data/debate_transcripts.rda")

# %%
df = data["debate_transcripts"]
df = df[df["type"] == "Pres"]

# %%
df
# Out:
#               speaker                                               text  \
# 119        Jim Lehrer  Good evening, and welcome to the first of 3 de...
# 120        Ross Perot  I think the principal that separates me is tha...
# 121        Jim Lehrer           Governor Clinton, a one minute response.
# 122      Bill Clinton  The most important distinction in this campaig...
# 123        Jim Lehrer  President Bush, one minute response, sir. PRES...
# ...               ...                                                ...
# 19430  Kristen Welker     All right. Vice President Biden, same question
# 19431       Joe Biden  I will say, I'm an American President. I repre...
# 19432       Joe Biden  We can grow this economy, we can deal with the...
# 19433  Kristen Welker  All right, I want to thank you both for a very...
# 19434       Joe Biden                                        Thank you.
#
#        type  election_year        date  candidate
# 119    Pres         1992.0  1992-10-11        0.0
# 120    Pres         1992.0  1992-10-11        1.0
# 121    Pres         1992.0  1992-10-11        0.0
# 122    Pres         1992.0  1992-10-11        1.0
# 123    Pres         1992.0  1992-10-11        0.0
# ...     ...            ...         ...        ...
# 19430  Pres         2020.0  2020-10-22        0.0
# 19431  Pres         2020.0  2020-10-22        1.0
# 19432  Pres         2020.0  2020-10-22        1.0
# 19433  Pres         2020.0  2020-10-22        0.0
# 19434  Pres         2020.0  2020-10-22        1.0
#
# [6897 rows x 6 columns]

# %%
years = df["election_year"].unique()
dates = df["date"].unique()

# %%
dates
# Out:
# array([datetime.date(1992, 10, 11), datetime.date(2000, 10, 11),
#        datetime.date(1960, 10, 13), datetime.date(1988, 10, 13),
#        datetime.date(2004, 10, 13), datetime.date(1992, 10, 15),
#        datetime.date(2008, 10, 15), datetime.date(1996, 10, 16),
#        datetime.date(2012, 10, 16), datetime.date(2000, 10, 17),
#        datetime.date(1992, 10, 19), datetime.date(2016, 10, 19),
#        datetime.date(1960, 10, 21), datetime.date(1984, 10, 21),
#        datetime.date(1976, 10, 22), datetime.date(2012, 10, 22),
#        datetime.date(1980, 10, 28), datetime.date(2000, 10, 3),
#        datetime.date(2012, 10, 3), datetime.date(1976, 10, 6),
#        datetime.date(1996, 10, 6), datetime.date(1960, 10, 7),
#        datetime.date(1984, 10, 7), datetime.date(2008, 10, 7),
#        datetime.date(2004, 10, 8), datetime.date(2016, 10, 9),
#        datetime.date(1980, 9, 21), datetime.date(1976, 9, 23),
#        datetime.date(1988, 9, 25), datetime.date(1960, 9, 26),
#        datetime.date(2008, 9, 26), datetime.date(2016, 9, 26),
#        datetime.date(2004, 9, 30), datetime.date(2020, 9, 29),
#        datetime.date(2020, 10, 22)], dtype=object)

# %%
first_debates = (
    df[["election_year", "date"]]
    .sort_values(by="date", ascending=False)
    .drop_duplicates(subset=["election_year"], keep="last")["date"]
    .values
)
first_debates
# Out:
# array([datetime.date(2020, 9, 29), datetime.date(2016, 9, 26),
#        datetime.date(2012, 10, 3), datetime.date(2008, 9, 26),
#        datetime.date(2004, 9, 30), datetime.date(2000, 10, 3),
#        datetime.date(1996, 10, 6), datetime.date(1992, 10, 11),
#        datetime.date(1988, 9, 25), datetime.date(1984, 10, 7),
#        datetime.date(1980, 9, 21), datetime.date(1976, 9, 23),
#        datetime.date(1960, 9, 26)], dtype=object)

# %%
df = df[df["date"].isin(first_debates)]

# %%
df
# Out:
#              speaker                                               text  type  \
# 119       Jim Lehrer  Good evening, and welcome to the first of 3 de...  Pres
# 120       Ross Perot  I think the principal that separates me is tha...  Pres
# 121       Jim Lehrer           Governor Clinton, a one minute response.  Pres
# 122     Bill Clinton  The most important distinction in this campaig...  Pres
# 123       Jim Lehrer  President Bush, one minute response, sir. PRES...  Pres
# ...              ...                                                ...   ...
# 18591   Donald Trump                         And I think he does, too.   Pres
# 18592  Chris Wallace                                   To be continued   Pres
# 18593  Chris Wallace    as - - in more debates, as we go on. Preside...  Pres
# 18594      Joe Biden                                              Yes.   Pres
# 18595  Chris Wallace    and the Cleveland Clinic for hosting this ev...  Pres
#
#        election_year        date  candidate
# 119           1992.0  1992-10-11        0.0
# 120           1992.0  1992-10-11        1.0
# 121           1992.0  1992-10-11        0.0
# 122           1992.0  1992-10-11        1.0
# 123           1992.0  1992-10-11        0.0
# ...              ...         ...        ...
# 18591         2020.0  2020-09-29        1.0
# 18592         2020.0  2020-09-29        0.0
# 18593         2020.0  2020-09-29        0.0
# 18594         2020.0  2020-09-29        1.0
# 18595         2020.0  2020-09-29        0.0
#
# [2906 rows x 6 columns]

# %%
df.to_csv("data/first_debates.csv", index=False)

# %%
pd.read_csv("data/first_debates.csv")
# Out:
#             speaker                                               text  type  \
# 0        Jim Lehrer  Good evening, and welcome to the first of 3 de...  Pres
# 1        Ross Perot  I think the principal that separates me is tha...  Pres
# 2        Jim Lehrer           Governor Clinton, a one minute response.  Pres
# 3      Bill Clinton  The most important distinction in this campaig...  Pres
# 4        Jim Lehrer  President Bush, one minute response, sir. PRES...  Pres
# ...             ...                                                ...   ...
# 2901   Donald Trump                         And I think he does, too.   Pres
# 2902  Chris Wallace                                   To be continued   Pres
# 2903  Chris Wallace    as - - in more debates, as we go on. Preside...  Pres
# 2904      Joe Biden                                              Yes.   Pres
# 2905  Chris Wallace    and the Cleveland Clinic for hosting this ev...  Pres
#
#       election_year        date  candidate
# 0            1992.0  1992-10-11        0.0
# 1            1992.0  1992-10-11        1.0
# 2            1992.0  1992-10-11        0.0
# 3            1992.0  1992-10-11        1.0
# 4            1992.0  1992-10-11        0.0
# ...             ...         ...        ...
# 2901         2020.0  2020-09-29        1.0
# 2902         2020.0  2020-09-29        0.0
# 2903         2020.0  2020-09-29        0.0
# 2904         2020.0  2020-09-29        1.0
# 2905         2020.0  2020-09-29        0.0
#
# [2906 rows x 6 columns]

# %%
for year in years:
    date = df[df["election_year"] == year]["date"].values[0]
    df[df["election_year"] == year].to_csv(f"data/by_date/{date}.csv", index=False)

# %%
data_base_dir = "data/by_date"

dates = []
dfs = {}
for fpath in glob.glob(data_base_dir + "/*"):
    df = pd.read_csv(fpath)
    date = df["date"].iloc[0]
    dfs[date] = df
    dates.append(date)

dates.sort()

# %%
parties = {
    "Dorothy Ridings": "Moderator",
    "Barbara Walters": "Moderator",
    "James Wieghart": "Moderator",
    "Walter Mondale": "Democratic",
    "Ronald Reagan": "Republican",
    "Dianne Sawyer": "Moderator",
    "Fred Barnes": "Moderator",
    "Jim Lehrer": "Moderator",
    "Bill Clinton": "Democratic",
    "Bob Dole": "Republican",
    "Howard Smith": "Moderator",
    "John Kennedy": "Democratic",
    "Richard Nixon": "Republican",
    "Bob Fleming": "Moderator",
    "Stuart Novins": "Moderator",
    "Charles Warren": "Moderator",
    "Sander Vanocur": "Moderator",
    "Voiceover": "Moderator",
    "Barack Obama": "Democratic",
    "Mitt Romney": "Republican",
    "George H. W. Bush": "Republican",
    "Michael Dukakis": "Democratic",
    "John Mashek": "Moderator",
    "Anne Groer": "Moderator",
    "Peter Jennings": "Moderator",
    "Moderator": "Moderator",
    "Al Gore": "Democratic",
    "George W. Bush": "Republican",
    "Ross Perot": "Reform",
    "Ann Compton": "Moderator",
    "Unknown": "Unknown",
    "John Anderson": "Independent",
    "Bill Moyers": "Moderator",
    "Carol Loomis": "Moderator",
    "Daniel Greenberg": "Moderator",
    "Charles Corddry": "Moderator",
    "Lee May": "Moderator",
    "Washington Post": "Moderator",
    "Bryant Quinn": "Moderator",
    "New York Times": "Moderator",
    "Soma Golden": "Moderator",
    "John McCain": "Republican",
    "Lester Holt": "Moderator",
    "Hillary Clinton": "Democratic",
    "Donald Trump": "Republican",
    "Chris Wallace": "Moderator",
    "Joe Biden": "Democratic",
    "Edwin Newman": "Moderator",
    "Frank Reynolds": "Moderator",
    "Jimmy Carter": "Democratic",
    "Gerald Ford": "Republican",
    "James Gannon": "Moderator",
    "Elizabeth Drew": "Moderator",
    "John Kerry": "Democratic",
}

# %%
i = 0

# %%
dfs[dates[i]]
# Out:
#           speaker                                               text  type  \
# 0    Howard Smith  Good evening. The television and radio station...  Pres
# 1    John Kennedy  Mr. Smith, Mr. Nixon. In the election of 1860,...  Pres
# 2    Howard Smith  And now the opening statement by Vice Presiden...  Pres
# 3   Richard Nixon  Mr. Smith, Senator Kennedy. The things that Se...  Pres
# 4    Howard Smith  Thank you, Mr. Nixon. That completes the openi...  Pres
# ..            ...                                                ...   ...
# 63   Howard Smith  Three minutes and twenty seconds for each cand...  Pres
# 64  Richard Nixon  Thank you, Mr. Smith. Senator Kennedy. First o...  Pres
# 65   Howard Smith                  Senator Kennedy, your conclusion.  Pres
# 66   John Kennedy  The point was made by Mr. Nixon that the Sovie...  Pres
# 67   Howard Smith  Thank you very much, gentlemen. This hour has ...  Pres
#
#     election_year        date  candidate  qud question  similarity_cls  \
# 0            1960  1960-09-26          0  NaN      NaN             NaN
# 1            1960  1960-09-26          1  NaN      NaN             NaN
# 2            1960  1960-09-26          0  NaN      NaN             NaN
# 3            1960  1960-09-26          1  NaN      NaN             NaN
# 4            1960  1960-09-26          0  NaN      NaN             NaN
# ..            ...         ...        ...  ...      ...             ...
# 63           1960  1960-09-26          0  NaN      NaN             NaN
# 64           1960  1960-09-26          1  NaN      NaN             NaN
# 65           1960  1960-09-26          0  NaN      NaN             NaN
# 66           1960  1960-09-26          1  NaN      NaN             NaN
# 67           1960  1960-09-26          0  NaN      NaN             NaN
#
#     similarity_max  similarity_mean  similarity_sbert
# 0              NaN              NaN               NaN
# 1              NaN              NaN               NaN
# 2              NaN              NaN               NaN
# 3              NaN              NaN               NaN
# 4              NaN              NaN               NaN
# ..             ...              ...               ...
# 63             NaN              NaN               NaN
# 64             NaN              NaN               NaN
# 65             NaN              NaN               NaN
# 66             NaN              NaN               NaN
# 67             NaN              NaN               NaN
#
# [68 rows x 12 columns]

# %%
dfs[dates[i]]["party"] = dfs[dates[i]].progress_apply(
    lambda row: parties[row["speaker"]], axis=1
)
# Out:
# 100%|██████████| 68/68 [00:00<00:00, 28618.57it/s]

# %%
dfs[dates[i]]
# Out:
#           speaker                                               text  type  \
# 0    Howard Smith  Good evening. The television and radio station...  Pres
# 1    John Kennedy  Mr. Smith, Mr. Nixon. In the election of 1860,...  Pres
# 2    Howard Smith  And now the opening statement by Vice Presiden...  Pres
# 3   Richard Nixon  Mr. Smith, Senator Kennedy. The things that Se...  Pres
# 4    Howard Smith  Thank you, Mr. Nixon. That completes the openi...  Pres
# ..            ...                                                ...   ...
# 63   Howard Smith  Three minutes and twenty seconds for each cand...  Pres
# 64  Richard Nixon  Thank you, Mr. Smith. Senator Kennedy. First o...  Pres
# 65   Howard Smith                  Senator Kennedy, your conclusion.  Pres
# 66   John Kennedy  The point was made by Mr. Nixon that the Sovie...  Pres
# 67   Howard Smith  Thank you very much, gentlemen. This hour has ...  Pres
#
#     election_year        date  candidate  qud question  similarity_cls  \
# 0            1960  1960-09-26          0  NaN      NaN             NaN
# 1            1960  1960-09-26          1  NaN      NaN             NaN
# 2            1960  1960-09-26          0  NaN      NaN             NaN
# 3            1960  1960-09-26          1  NaN      NaN             NaN
# 4            1960  1960-09-26          0  NaN      NaN             NaN
# ..            ...         ...        ...  ...      ...             ...
# 63           1960  1960-09-26          0  NaN      NaN             NaN
# 64           1960  1960-09-26          1  NaN      NaN             NaN
# 65           1960  1960-09-26          0  NaN      NaN             NaN
# 66           1960  1960-09-26          1  NaN      NaN             NaN
# 67           1960  1960-09-26          0  NaN      NaN             NaN
#
#     similarity_max  similarity_mean  similarity_sbert       party
# 0              NaN              NaN               NaN   Moderator
# 1              NaN              NaN               NaN  Democratic
# 2              NaN              NaN               NaN   Moderator
# 3              NaN              NaN               NaN  Republican
# 4              NaN              NaN               NaN   Moderator
# ..             ...              ...               ...         ...
# 63             NaN              NaN               NaN   Moderator
# 64             NaN              NaN               NaN  Republican
# 65             NaN              NaN               NaN   Moderator
# 66             NaN              NaN               NaN  Democratic
# 67             NaN              NaN               NaN   Moderator
#
# [68 rows x 13 columns]

# %%
for i in tqdm(range(len(dates))):
    dfs[dates[i]]["party"] = dfs[dates[i]].apply(
        lambda row: parties[row["speaker"]], axis=1
    )
    dfs[dates[i]].to_csv(f"{data_base_dir}/{dates[i]}.csv", index=False)
# Out:
# 100%|██████████| 13/13 [00:00<00:00, 216.63it/s]
